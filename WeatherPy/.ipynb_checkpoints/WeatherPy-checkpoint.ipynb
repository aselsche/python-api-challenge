# %%
#Dependencies setup
import pandas as pd
import matplotlib.pyplot as plt
import requests
import scipy.stats as st
import numpy as np
import scipy.stats as linregress
#from scipy import stats

#incorporate citipy to populate cities
from citipy import citipy

#Import API Key
from config import api_key

# %%
# a set will only allo unique entries so we can ensure cities are unique
cities=set()

# ensure loop runs until len of set is exactly 800 cities
while len(cities) < 150:
    # Identify nearest city for a random latitude, lonngtitue coorinate
    lat = np.random.randint(-90, 90)
    lon = np.random.randint(-180, 180)
    city = citipy.nearest_city(lat, lon)
#     countries = citipy.nearest_city(lat, lon).country_code
    cities.add(f'{city.city_name},{city.country_code}')

    
# Print the city count to confirm sufficient count
cities
# Out:
# {'adiake,ci',
#  'airai,pw',
#  'aklavik,ca',
#  'albany,au',
#  'alta floresta,br',
#  'amderma,ru',
#  'anadyr,ru',
#  'arraial do cabo,br',
#  'attawapiskat,ca',
#  'atuona,pf',
#  'avarua,ck',
#  'avera,pf',
#  'awbari,ly',
#  'baherden,tm',
#  'bambous virieux,mu',
#  'bambui,br',
#  'bardiyah,ly',
#  'barrow,us',
#  'bela,pk',
#  'belmonte,br',
#  'beloha,mg',
#  'belushya guba,ru',
#  'bethel,us',
#  'bheramara,bd',
#  'bluff,nz',
#  'bredasdorp,za',
#  'broome,au',
#  'bubaque,gw',
#  'burnie,au',
#  'busselton,au',
#  'butaritari,ki',
#  'calvinia,za',
#  'cape town,za',
#  'carnarvon,au',
#  'cartagena del chaira,co',
#  'castro,cl',
#  'chokurdakh,ru',
#  'cidreira,br',
#  'diapaga,bf',
#  'dikson,ru',
#  'dudinka,ru',
#  'esperance,au',
#  'faanui,pf',
#  'fevralsk,ru',
#  'fortuna,us',
#  'guerrero negro,mx',
#  'half moon bay,us',
#  'hambantota,lk',
#  'hermanus,za',
#  'hilo,us',
#  'hithadhoo,mv',
#  'hobart,au',
#  'husavik,is',
#  'illoqqortoormiut,gl',
#  'iralaya,hn',
#  'iskateley,ru',
#  'istanbul,tr',
#  'jamestown,sh',
#  'jining,cn',
#  'kaduqli,sd',
#  'kahului,us',
#  'kapaa,us',
#  'kenai,us',
#  'khatanga,ru',
#  'kidal,ml',
#  'kindu,cd',
#  'kodiak,us',
#  'korla,cn',
#  'lahat,id',
#  'lata,sb',
#  'lavrentiya,ru',
#  'lebu,cl',
#  'lindi,tz',
#  'lingyuan,cn',
#  'loandjili,cg',
#  'louisbourg,ca',
#  'mallaig,gb',
#  'manchar,in',
#  'mangan,in',
#  'manicore,br',
#  'mar del plata,ar',
#  'marabba,sd',
#  'marcona,pe',
#  'mareeba,au',
#  'marovoay,mg',
#  'mataura,pf',
#  'mayo,ca',
#  'mbanza-ngungu,cd',
#  'muli,mv',
#  'muscatine,us',
#  'nadym,ru',
#  'naze,jp',
#  'nikolskoye,ru',
#  'nizhneudinsk,ru',
#  'nizhneyansk,ru',
#  'norman wells,ca',
#  'novobirilyussy,ru',
#  'novyy urengoy,ru',
#  'olinda,br',
#  'osinovo,ru',
#  'pacifica,us',
#  'palana,ru',
#  'palasa,in',
#  'pangody,ru',
#  'parras,mx',
#  'pedernales,do',
#  'pevek,ru',
#  'plettenberg bay,za',
#  'pochutla,mx',
#  'port alfred,za',
#  'port-cartier,ca',
#  'puerto ayora,ec',
#  'punta arenas,cl',
#  'qaanaaq,gl',
#  'quang ngai,vn',
#  'quimper,fr',
#  'ribeira grande,pt',
#  'rikitea,pf',
#  'rostovka,ru',
#  'sa kaeo,th',
#  'saleaula,ws',
#  'sao joao da barra,br',
#  'saskylakh,ru',
#  'severo-kurilsk,ru',
#  'shingu,jp',
#  'shitkino,ru',
#  'sibolga,id',
#  'sindor,ru',
#  'tabou,ci',
#  'talnakh,ru',
#  'taolanaro,mg',
#  'tasiilaq,gl',
#  'te anau,nz',
#  'tezu,in',
#  'thompson,ca',
#  'tiksi,ru',
#  'tocopilla,cl',
#  'tsihombe,mg',
#  'tubruq,ly',
#  'tuktoyaktuk,ca',
#  'ushuaia,ar',
#  'ust-kamchatsk,ru',
#  'uwayl,sd',
#  'vaini,to',
#  'vaitupu,wf',
#  'victoria,sc',
#  'waddan,ly',
#  'yellowknife,ca',
#  'yulara,au',
#  'zhuhai,cn'}

# %%
# Perform API Calls
# Perform a weather check on each city using a series of successive API calls.
# Include a print log of each city as it'sbeing processed (with the city number and city name).

# Loop through the list of cities and perform a request for data on each
units = "imperial"
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={api_key}&units={units}&q="

# track list of lists to create data frame
cities_for_df = []
lat = []
lon = []
temp_max = []
humidity = []
cloudiness = []
wind_speed = []
countries = []
date = []

for i, city in enumerate(cities):
    print(f"Processing Record {i} | {city}")
    try:
        response = requests.get(f"{query_url}{city}").json()
    
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        cities_for_df.append(city)
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        countries.append(response['sys']['country'])
        date.append(response['dt'])
    except (KeyError, IndexError):
        print(f'Error requesting weather for {city}')
        
df2 = pd.DataFrame({
    'City': cities_for_df,
    'Lat': lat,
    'Lng': lon,
    'Max Temp': temp_max,
    'Humidity': humidity,
    'Cloudiness': cloudiness,
    'Wind Speed': wind_speed,
    'Country': countries,
    'Date': date
})

df2
# Out:
# Processing Record 0 | kapaa,us
# Processing Record 1 | istanbul,tr
# Processing Record 2 | loandjili,cg
# Processing Record 3 | manchar,in
# Processing Record 4 | cartagena del chaira,co
# Processing Record 5 | novyy urengoy,ru
# Processing Record 6 | kidal,ml
# Processing Record 7 | calvinia,za
# Processing Record 8 | lata,sb
# Error requesting weather for lata,sb
# Processing Record 9 | hilo,us
# Processing Record 10 | pacifica,us
# Processing Record 11 | punta arenas,cl
# Processing Record 12 | manicore,br
# Processing Record 13 | anadyr,ru
# Processing Record 14 | tezu,in
# Processing Record 15 | lindi,tz
# Processing Record 16 | tocopilla,cl
# Processing Record 17 | pedernales,do
# Processing Record 18 | belushya guba,ru
# Error requesting weather for belushya guba,ru
# Processing Record 19 | uwayl,sd
# Error requesting weather for uwayl,sd
# Processing Record 20 | parras,mx
# Error requesting weather for parras,mx
# Processing Record 21 | jamestown,sh
# Processing Record 22 | attawapiskat,ca
# Error requesting weather for attawapiskat,ca
# Processing Record 23 | kindu,cd
# Processing Record 24 | tsihombe,mg
# Error requesting weather for tsihombe,mg
# Processing Record 25 | baherden,tm
# Processing Record 26 | sibolga,id
# Processing Record 27 | port alfred,za
# Processing Record 28 | cape town,za
# Processing Record 29 | awbari,ly
# Processing Record 30 | nadym,ru
# Processing Record 31 | taolanaro,mg
# Error requesting weather for taolanaro,mg
# Processing Record 32 | broome,au
# Processing Record 33 | mayo,ca
# Processing Record 34 | mangan,in
# Processing Record 35 | hithadhoo,mv
# Processing Record 36 | barrow,us
# Processing Record 37 | pevek,ru
# Processing Record 38 | aklavik,ca
# Processing Record 39 | muli,mv
# Processing Record 40 | muscatine,us
# Processing Record 41 | beloha,mg
# Processing Record 42 | zhuhai,cn
# Processing Record 43 | marabba,sd
# Processing Record 44 | osinovo,ru
# Processing Record 45 | ust-kamchatsk,ru
# Error requesting weather for ust-kamchatsk,ru
# Processing Record 46 | avarua,ck
# Processing Record 47 | kahului,us
# Processing Record 48 | butaritari,ki
# Processing Record 49 | mallaig,gb
# Processing Record 50 | amderma,ru
# Error requesting weather for amderma,ru
# Processing Record 51 | saskylakh,ru
# Processing Record 52 | yulara,au
# Processing Record 53 | bluff,nz
# Processing Record 54 | louisbourg,ca
# Error requesting weather for louisbourg,ca
# Processing Record 55 | alta floresta,br
# Processing Record 56 | sa kaeo,th
# Processing Record 57 | ribeira grande,pt
# Processing Record 58 | rikitea,pf
# Processing Record 59 | airai,pw
# Error requesting weather for airai,pw
# Processing Record 60 | puerto ayora,ec
# Processing Record 61 | shingu,jp
# Processing Record 62 | bambui,br
# Processing Record 63 | fevralsk,ru
# Error requesting weather for fevralsk,ru
# Processing Record 64 | lebu,cl
# Processing Record 65 | sindor,ru
# Processing Record 66 | port-cartier,ca
# Processing Record 67 | nizhneyansk,ru
# Error requesting weather for nizhneyansk,ru
# Processing Record 68 | nizhneudinsk,ru
# Processing Record 69 | iralaya,hn
# Processing Record 70 | iskateley,ru
# Processing Record 71 | faanui,pf
# Processing Record 72 | diapaga,bf
# Processing Record 73 | dudinka,ru
# Processing Record 74 | olinda,br
# Processing Record 75 | dikson,ru
# Processing Record 76 | hambantota,lk
# Processing Record 77 | palasa,in
# Processing Record 78 | lavrentiya,ru
# Processing Record 79 | hobart,au
# Processing Record 80 | mataura,pf
# Error requesting weather for mataura,pf
# Processing Record 81 | kenai,us
# Processing Record 82 | half moon bay,us
# Processing Record 83 | esperance,au
# Processing Record 84 | bardiyah,ly
# Processing Record 85 | ushuaia,ar
# Processing Record 86 | saleaula,ws
# Error requesting weather for saleaula,ws
# Processing Record 87 | bela,pk
# Processing Record 88 | bubaque,gw
# Processing Record 89 | tabou,ci
# Processing Record 90 | illoqqortoormiut,gl
# Error requesting weather for illoqqortoormiut,gl
# Processing Record 91 | quang ngai,vn
# Processing Record 92 | te anau,nz
# Processing Record 93 | korla,cn
# Processing Record 94 | thompson,ca
# Processing Record 95 | mar del plata,ar
# Processing Record 96 | bheramara,bd
# Processing Record 97 | vaini,to
# Processing Record 98 | waddan,ly
# Processing Record 99 | shitkino,ru
# Processing Record 100 | busselton,au
# Processing Record 101 | lingyuan,cn
# Processing Record 102 | palana,ru
# Processing Record 103 | novobirilyussy,ru
# Processing Record 104 | yellowknife,ca
# Processing Record 105 | plettenberg bay,za
# Processing Record 106 | hermanus,za
# Processing Record 107 | bambous virieux,mu
# Processing Record 108 | belmonte,br
# Processing Record 109 | jining,cn
# Processing Record 110 | tiksi,ru
# Processing Record 111 | marcona,pe
# Error requesting weather for marcona,pe
# Processing Record 112 | tubruq,ly
# Error requesting weather for tubruq,ly
# Processing Record 113 | avera,pf
# Error requesting weather for avera,pf
# Processing Record 114 | victoria,sc
# Processing Record 115 | atuona,pf
# Processing Record 116 | khatanga,ru
# Processing Record 117 | marovoay,mg
# Processing Record 118 | chokurdakh,ru
# Processing Record 119 | talnakh,ru
# Processing Record 120 | naze,jp
# Processing Record 121 | quimper,fr
# Processing Record 122 | vaitupu,wf
# Error requesting weather for vaitupu,wf
# Processing Record 123 | lahat,id
# Processing Record 124 | carnarvon,au
# Processing Record 125 | pochutla,mx
# Processing Record 126 | mbanza-ngungu,cd
# Processing Record 127 | norman wells,ca
# Processing Record 128 | bredasdorp,za
# Processing Record 129 | nikolskoye,ru
# Processing Record 130 | kodiak,us
# Processing Record 131 | burnie,au
# Processing Record 132 | severo-kurilsk,ru
# Processing Record 133 | qaanaaq,gl
# Processing Record 134 | tasiilaq,gl
# Processing Record 135 | husavik,is
# Processing Record 136 | castro,cl
# Processing Record 137 | arraial do cabo,br
# Processing Record 138 | bethel,us
# Processing Record 139 | fortuna,us
# Processing Record 140 | tuktoyaktuk,ca
# Processing Record 141 | guerrero negro,mx
# Processing Record 142 | albany,au
# Processing Record 143 | cidreira,br
# Processing Record 144 | sao joao da barra,br
# Processing Record 145 | mareeba,au
# Processing Record 146 | rostovka,ru
# Processing Record 147 | adiake,ci
# Processing Record 148 | pangody,ru
# Processing Record 149 | kaduqli,sd
#                         City      Lat       Lng  Max Temp  Humidity  \
# 0                   kapaa,us  22.0752 -159.3190     82.38        80
# 1                istanbul,tr  41.0351   28.9833     75.06        73
# 2               loandjili,cg  -4.7561   11.8578     73.51        83
# 3                 manchar,in  19.0000   73.9333     71.74        94
# 4    cartagena del chaira,co   1.3349  -74.8429     69.08        99
# ..                       ...      ...       ...       ...       ...
# 125               mareeba,au -17.0000  145.4333     81.32        55
# 126              rostovka,ru  55.3842   71.8891     70.50        54
# 127                adiake,ci   5.2863   -3.3040     76.59        87
# 128               pangody,ru  65.8500   74.4859     59.18        84
# 129               kaduqli,sd  11.0167   29.7167     72.12        91
#
#      Cloudiness  Wind Speed Country        Date
# 0            75        3.00      US  1626920603
# 1             0       12.66      TR  1626920604
# 2            90        5.75      CG  1626920604
# 3           100       15.01      IN  1626920604
# 4           100        1.77      CO  1626920605
# ..          ...         ...     ...         ...
# 125          51        5.30      AU  1626920638
# 126          55       10.87      RU  1626920639
# 127          65        5.68      CI  1626920639
# 128         100       17.52      RU  1626920639
# 129          99        4.56      SD  1626920639
#
# [130 rows x 9 columns]

# %%
#Save dataframe
df2.to_csv("Output/city_data.csv", index=False, header=True)

df2[['Lat', 'Lng', 'Max Temp', 'Humidity', 
     'Cloudiness', 'Wind Speed']].describe(include='all')
# Out:
#               Lat         Lng   Max Temp    Humidity  Cloudiness  Wind Speed
# count  125.000000  125.000000  125.00000  125.000000  125.000000  125.000000
# mean    16.983610   11.615205   66.52840   75.696000   63.008000    8.690320
# std     37.812479   97.775687   13.93295   13.408726   39.335098    6.383828
# min    -54.800000 -175.200000   31.84000   38.000000    0.000000    0.000000
# 25%    -16.483300  -70.197900   55.36000   68.000000   20.000000    3.910000
# 50%     18.038400   23.371600   69.64000   77.000000   82.000000    6.870000
# 75%     55.743500   90.666100   78.55000   85.000000  100.000000   12.660000
# max     77.484000  177.483300   89.38000  100.000000  100.000000   35.050000

# %%
## Inspect the data and remove the cities where the humidity > 100%.
#  Get the indices of cities that have humidity over 100%.
cond = df2['Humidity'] > 100.0
df2.index[cond]
# Out:
# Int64Index([], dtype='int64')

# %%
# would keep our entire list as no cities over 100%
df2 = df2[~cond]
df2
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# 0                   kapaa,us  22.0752 -159.3190     82.38        80
# 1                istanbul,tr  41.0351   28.9833     75.06        73
# 2               loandjili,cg  -4.7561   11.8578     73.51        83
# 3                 manchar,in  19.0000   73.9333     71.74        94
# 4    cartagena del chaira,co   1.3349  -74.8429     69.08        99
# ..                       ...      ...       ...       ...       ...
# 125               mareeba,au -17.0000  145.4333     81.32        55
# 126              rostovka,ru  55.3842   71.8891     70.50        54
# 127                adiake,ci   5.2863   -3.3040     76.59        87
# 128               pangody,ru  65.8500   74.4859     59.18        84
# 129               kaduqli,sd  11.0167   29.7167     72.12        91
#
#      Cloudiness  Wind Speed Country        Date
# 0            75        3.00      US  1626920603
# 1             0       12.66      TR  1626920604
# 2            90        5.75      CG  1626920604
# 3           100       15.01      IN  1626920604
# 4           100        1.77      CO  1626920605
# ..          ...         ...     ...         ...
# 125          51        5.30      AU  1626920638
# 126          55       10.87      RU  1626920639
# 127          65        5.68      CI  1626920639
# 128         100       17.52      RU  1626920639
# 129          99        4.56      SD  1626920639
#
# [130 rows x 9 columns]

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# using scipy to calculate z-score which is a score of an items relationship to the standard dev and mean.
# a score more than 3 or less than -3 customarily indicates an outlier
cond = np.abs(linregress.zscore(df2['Humidity'])) > 3

df2.drop(df2[cond].index,inplace=True)

# %%
#Savea a copy of the city_data DataFrame, which we call "clean_city_data".
df2.to_csv("Output/clean_city_data.csv", index=False, header=True)

# %%
# Your first requirement is to create a series of scatter plots to showcase the following relationships:

        # Temperature (F) vs. Latitude
        # Humidity (%) vs. Latitude
        # Cloudiness (%) vs. Latitude
        # Wind Speed (mph) vs. Latitude

# %%
#Latitude vs. Temperature Plot

plt.scatter(df2["Lat"],df2["Max Temp"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Figures/fig1.png")
plt.show()

# %%
 # Humidity (%) vs. Latitude
    
plt.scatter(df2["Humidity"],df2["Lat"],edgecolors="black",facecolors="skyblue")
plt.title("Humidity vs. Latitude")
plt.xlabel("Humidity %")
plt.ylabel("Latitude")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Figures/fig2.png")
plt.show()

# %%
  # Cloudiness (%) vs. Latitude
plt.scatter(df2["Cloudiness"],df2["Lat"],edgecolors="black",facecolors="skyblue")
plt.title("Cloudiness vs. Latitude")
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Figures/fig3.png")
plt.show()

# %%
   # Wind Speed (mph) vs. Latitude
plt.scatter(df2["Wind Speed"],df2["Lat"],edgecolors="black",facecolors="skyblue")
plt.title("Wind Speed vs. Latitude")
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Figures/fig4.png")
plt.show()
